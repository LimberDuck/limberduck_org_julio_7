# %% [markdown]
# # CPE

# %% [markdown]
# **Common Platform Enumeration (CPE)** is a structured naming scheme for information technology systems, software, and packages. Based upon the generic syntax for Uniform Resource Identifiers (URI), CPE includes a formal name format, a method for checking names against a system, and a description format for binding text and tests to a name. This method of naming is known as a well-formed CPE name (WFN)
#
# > source: [cpe.mitre.org/specification](https://cpe.mitre.org/specification/)

# %% [markdown]
# You can see this notebook directly via:
# - [GitHub](https://github.com/LimberDuck/limberduck_org_julio_7/blob/master/docs/notebooks/cpe/cpe.ipynb)
# - [Jupter nbviewer](https://nbviewer.org/github/LimberDuck/limberduck_org_julio_7/blob/master/docs/notebooks/cpe/cpe.ipynb)

# %% [markdown]
# ## Generation time

# %%
from datetime import datetime, timezone, timedelta

timezone_offset = 0.0
tzinfo = timezone(timedelta(hours=timezone_offset))
generation_time = datetime.now(tzinfo).strftime('%Y-%m-%d %H:%M:%S %z')
print(generation_time)
# Out:
# 2024-04-16 05:54:00 +0000

# %% [markdown]
# ## Creative Commons

# %% [markdown]
# This notebook and generated diagrams are released with [Creative Commons liecense (CC BY 4.0)](https://creativecommons.org/licenses/by/4.0/deed.en).
#
# <a href="https://creativecommons.org/licenses/by/4.0/deed.en"><img src="https://mirrors.creativecommons.org/presskit/buttons/88x31/png/by.png" alt="CC BY 4.0" width="100px"/></a>

# %%
import requests
import urllib3

urllib3.disable_warnings()

urls = ['https://mirrors.creativecommons.org/presskit/icons/cc.xlarge.png',
       'https://mirrors.creativecommons.org/presskit/icons/by.xlarge.png']
for url in urls:
    file_name = url.split("/")[-1:][0]
    print(file_name)

    file = requests.get(url, verify=False)
    open(file_name, 'wb').write(file.content)
# Out:
# cc.xlarge.png
# by.xlarge.png

# %% [markdown]
# ## CPE data downloading
#
# All CPE stats are taken from [nvd.nist.gov/products/cpe/statistics](https://nvd.nist.gov/products/cpe/statistics)

# %%
from urllib.request import urlopen
import ssl
from bs4 import BeautifulSoup, SoupStrainer

def get_data(url):

    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE

    page = urlopen(url, context=ctx)
    html = page.read().decode("utf-8")
    
    product = SoupStrainer('table')
    soup = BeautifulSoup(html, "html.parser", parse_only=product)
    
    return soup

url = "https://nvd.nist.gov/products/cpe/statistics"
data = get_data(url)

print(len(data))
# Out:
# 16

# %% [markdown]
# ## New CPE entries

# %% [markdown]
# ### CPE data parsing

# %%
import pandas as pd

def pars(data):
    data_table = []
    
    for table in data:
        table_id = table['id']
        table_year = table_id[-4:]
        table_rows = table.find_all("tr")
        number_of_new_cpe_entries_yearly = 0
        number_of_new_cpe_entries_list = []
        data_row = []
        for table_row in table_rows:
            data = table_row.find_all("td")
            
            if data:
                number_of_new_cpe_entries = int(data[1].string.replace(",",""))
                
                number_of_new_cpe_entries_list.append(number_of_new_cpe_entries)
                
                number_of_new_cpe_entries_yearly += number_of_new_cpe_entries
        
        while len(number_of_new_cpe_entries_list) < 12:
            number_of_new_cpe_entries_list.append(0)

        data_row.append(table_year)
        data_row.append(number_of_new_cpe_entries_yearly)
        data_row = data_row + number_of_new_cpe_entries_list

        data_table.append(data_row)
    
    data_columns = ['Year', 'Summary', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
    df = pd.DataFrame (data_table, columns = data_columns)
    df.sort_values(by=['Year'], inplace=True)    
    df.reset_index(drop=True, inplace=True)
    df.index += 1
    return df
    
parsed_data = pars(data)

parsed_data.style.bar(subset=['Summary'], color='#FF6200')
# Out:
# <style type="text/css">
# #T_8f994_row0_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_8f994_row1_col1, #T_8f994_row7_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 2.0%, transparent 2.0%);
# }
# #T_8f994_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 1.3%, transparent 1.3%);
# }
# #T_8f994_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 6.5%, transparent 6.5%);
# }
# #T_8f994_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 3.7%, transparent 3.7%);
# }
# #T_8f994_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 4.1%, transparent 4.1%);
# }
# #T_8f994_row6_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 0.3%, transparent 0.3%);
# }
# #T_8f994_row8_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 4.8%, transparent 4.8%);
# }
# #T_8f994_row9_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 19.0%, transparent 19.0%);
# }
# #T_8f994_row10_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 100.0%, transparent 100.0%);
# }
# #T_8f994_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 62.2%, transparent 62.2%);
# }
# #T_8f994_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 69.0%, transparent 69.0%);
# }
# #T_8f994_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 63.8%, transparent 63.8%);
# }
# #T_8f994_row14_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 81.5%, transparent 81.5%);
# }
# #T_8f994_row15_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FF6200 12.7%, transparent 12.7%);
# }
# </style>
# <table id="T_8f994_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Summary</th>
#       <th class="col_heading level0 col2" >January</th>
#       <th class="col_heading level0 col3" >February</th>
#       <th class="col_heading level0 col4" >March</th>
#       <th class="col_heading level0 col5" >April</th>
#       <th class="col_heading level0 col6" >May</th>
#       <th class="col_heading level0 col7" >June</th>
#       <th class="col_heading level0 col8" >July</th>
#       <th class="col_heading level0 col9" >August</th>
#       <th class="col_heading level0 col10" >September</th>
#       <th class="col_heading level0 col11" >October</th>
#       <th class="col_heading level0 col12" >November</th>
#       <th class="col_heading level0 col13" >December</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f994_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8f994_row0_col0" class="data row0 col0" >2009</td>
#       <td id="T_8f994_row0_col1" class="data row0 col1" >5786</td>
#       <td id="T_8f994_row0_col2" class="data row0 col2" >181</td>
#       <td id="T_8f994_row0_col3" class="data row0 col3" >422</td>
#       <td id="T_8f994_row0_col4" class="data row0 col4" >830</td>
#       <td id="T_8f994_row0_col5" class="data row0 col5" >639</td>
#       <td id="T_8f994_row0_col6" class="data row0 col6" >612</td>
#       <td id="T_8f994_row0_col7" class="data row0 col7" >209</td>
#       <td id="T_8f994_row0_col8" class="data row0 col8" >241</td>
#       <td id="T_8f994_row0_col9" class="data row0 col9" >110</td>
#       <td id="T_8f994_row0_col10" class="data row0 col10" >330</td>
#       <td id="T_8f994_row0_col11" class="data row0 col11" >102</td>
#       <td id="T_8f994_row0_col12" class="data row0 col12" >1960</td>
#       <td id="T_8f994_row0_col13" class="data row0 col13" >150</td>
#     </tr>
#     <tr>
#       <th id="T_8f994_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_
level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8f994_row4_col0" class="data row4 col0" >2013</td>
#       <td id="T_8f994_row4_col1" class="data row4 col1" >15671</td>
#       <td id="T_8f994_row4_col2" class="data row4 col2" >1460</td>
#       <td id="T_8f994_row4_col3" class="data row4 col3" >1105</td>
#       <td id="T_8f994_row4_col4" class="data row4 col4" >1138</td>
#       <td id="T_8f994_row4_col5" class="data row4 col5" >1271</td>
#       <td id="T_8f994_row4_col6" class="data row4 col6" >932</td>
#       <td id="T_8f994_row4_col7" class="data row4 col7" >989</td>
#       <td id="T_8f994_row4_col8" class="data row4 col8" >1623</td>
#       <td id="T_8f994_row4_col9" class="data row4 col9" >1359</td>
#       <td id="T_8f994_row4_col10" class="data row4 col10" >1140</td>
#       <td id="T_8f994_row4_col11" class="data row4 col11" >1941</td>
#       <td id="T_8f994_row4_col12" class="data row4 col12" >1327</td>
#       <td id="T_8f994_row4_col13" class="data row4 col13" >1386</td>
#     </tr>
#     <tr>
#       <th id="T_8f994_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8f

# %% [markdown]
# ### CPE data saving

# %% [markdown]
# CSV file is available in GitHub repository, see:
#
# - [file via GitHub](https://github.com/LimberDuck/limberduck_org_julio_7/blob/master/docs/notebooks/cpe/cpe-number-of-new-entries.csv)
# - [file directly](https://raw.githubusercontent.com/limberduck_org_julio_7/limberduck.org/master/docs/notebooks/cpe/cpe-number-of-new-entries.csv)

# %%
csv_filename = 'cpe-number-of-new-entries.csv'

parsed_data.to_csv(csv_filename, index=False)

# %% [markdown]
# ### CPE data ploting

# %% [markdown]
# PNG files are available in GitHub repository with two background versions, see:
#
# - [file via GitHub (white background)](https://github.com/LimberDuck/limberduck_org_julio_7/blob/master/docs/notebooks/cpe/cpe-number-of-new-entries-bg-white.png)
# - [file via GitHub (transparent background)](https://github.com/LimberDuck/limberduck_org_julio_7/blob/master/docs/notebooks/cpe/cpe-number-of-new-entries-bg-transparent.png)
# - [file directly (white background)](https://raw.githubusercontent.com/LimberDuck/limberduck_org_julio_7/master/docs/notebooks/cpe/cpe-number-of-new-entries-bg-white.png)
# - [file directly (transparent background)](https://raw.githubusercontent.com/LimberDuck/limberduck_org_julio_7/master/docs/notebooks/cpe/cpe-number-of-new-entries-bg-transparent.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import urllib

df = pd.read_csv(csv_filename)

df.plot(x='Year', 
        xlabel='Year',
        y='Summary', 
        ylabel='Number of CPE',
        kind='bar', 
        title='Number of CPE per year')
plt.tight_layout()
plt.legend(['CPE'])
plt.figtext(0.16, 0.02, f"Generated on {generation_time} thanks to limberduck.org based on source: nvd.nist.gov/products/cpe/statistics", ha="left", fontsize=7)
fig = plt.gcf()
fig.set_size_inches(10,6)
fig.patch.set_facecolor('white')
plt.grid(True)

img_cc = plt.imread('cc.xlarge.png')
newax_cc = fig.add_axes([0.88, 0.0, 0.05, 0.05], anchor='NE', zorder=-1)
newax_cc.imshow(img_cc)
newax_cc.axis('off')
img_by = plt.imread('by.xlarge.png')
newax_by = fig.add_axes([0.92, 0.0, 0.05, 0.05], anchor='NE', zorder=-1)
newax_by.imshow(img_by)
newax_by.axis('off')

plt.savefig('cpe-number-of-new-entries-bg-white.png', dpi = 300, facecolor = 'white')
plt.savefig('cpe-number-of-new-entries-bg-transparent.png', dpi = 300, transparent = True)
